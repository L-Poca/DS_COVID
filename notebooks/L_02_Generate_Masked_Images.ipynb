# %%
# importation des bibliothèques basiques
from pathlib import Path
import sys
import os
from IPython.display import display
import pandas as pd

# Ajout du répertoire racine du projet au PYTHONPATH pour tous les imports
project_root = Path().resolve().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# Ensuite importer les modules nécessaires
import src.features.Traitement_Data.traitement_modulaire as traitement_modulaire
import src.features.Traitement_Data.C_traitement as C_traitement


# Configuration de l'affichage des graphiques
paths = C_traitement.Get_All_Paths_2()
dsize = (128, 128)  # Taille de redimensionnement des images

# Fonction pour afficher les images et leurs statistiques
import matplotlib.pyplot as plt
def afficher_images_et_stats(images_masked, stats_list, FileName):
    """Affiche les images et leurs statistiques."""

    # Affichage des images et statistiques
    print(f"Displaying first 5 images and stats for {FileName}...")
    for i, img in enumerate(images_masked[:5]):
        plt.figure()
        cmap='gray' if len(img.shape)==2 else "RGB"
        plt.imshow(img, cmap=cmap)
        plt.title(f"Image {img.shape} - {FileName} - {cmap}")
        plt.axis('off')
        plt.show()
        display(stats_list[i])

def Afficher_statistiques(list_stat, FileName):
    """Affiche les statistiques du DataFrame."""
    print(f"Displaying statistics for {FileName}...")
    # Création d'un DataFrame à partir de la liste de statistiques
    df = pd.DataFrame(list_stat)
    df['FileName'] = FileName  # Ajout du nom de fichier pour référence
    # Affichage des statistiques
    display(df)
    display(df.describe())
    display(df.head())

    #visualisation des statistiques
    df.hist(figsize=(10, 10), bins=30)
    # Affichage des graphiques
    plt.suptitle(f"Statistiques pour {FileName}")
    plt.show()







# Traitement des images par catégorie
print("Starting image processing...")

Stats = {}

for key, path_dict in paths.items():

    # Récupération des chemins d'image et de masque
    img_path = path_dict.get("img")
    mask_path = path_dict.get("mask")

    # Vérification de l'existence des masques
    print(f"Processing images in {key} {'with masks' if mask_path else 'without masks'}...")
    
    # Nom du fichier de sortie
    FileName = f"{key}_{dsize[0]}x{dsize[1]}{'_masked' if mask_path else ''}"

    # Traitement des images
    save_images = True
    df, images_masked, stats_list = traitement_modulaire.main_workflow(
        image_folder=img_path,
        dsize=dsize,
        Categorie= key,
        grayscale=True,
        flat_array=True,
        mask_folder=mask_path,
        show_each=False,
        FileName=FileName,
        export_csv=False, # ne pas utiliser pour l'instant, c'est les numpy arrays des images qui sont sauvegardés
        save_images=True # pour sauvegarder les images traitées, Dossier-Automatique par resolution et categories
    )

    # Sauvegarde des statistiques dans le dictionnaire
    Stats[key] = stats_list

    # Affichage des résultats
    #display(df.head())
    #afficher_images_et_stats(images_masked, stats_list, FileName)

for key, stats_list in Stats.items():
    # Affichage des statistiques pour chaque catégorie
    Afficher_statistiques(stats_list, FileName)
# Out:
# Starting image processing...
# Processing images in covid with masks...
# Nombre d'images trouvées : 3616
# Image 3616/3616 traitée : COVID-999.pngg
# Image 3616/3616 traitée : COVID-999.png
# DataFrame shape : (3616, 16393)
# Processing images in normal with masks...
# Nombre d'images trouvées : 10192
# DataFrame shape : (3616, 16393)-10030.png
# Processing images in normal with masks...
# Nombre d'images trouvées : 10192
# Image 10192/10192 traitée : Normal-9999.png
# Image 10192/10192 traitée : Normal-9999.png
# DataFrame shape : (10192, 16393)
# DataFrame shape : (10192, 16393)
# Processing images in lung with masks...
# Nombre d'images trouvées : 6012
# Processing images in lung with masks...32.png
# Nombre d'images trouvées : 6012
# Image 6012/6012 traitée : Lung_Opacity-999.pngg
# Image 6012/6012 traitée : Lung_Opacity-999.png
# DataFrame shape : (6012, 16393)
# DataFrame shape : (6012, 16393)
# Processing images in pneumonia with masks...
# Nombre d'images trouvées : 1345
# Processing images in pneumonia with masks....png
# Nombre d'images trouvées : 1345
# Image 1345/1345 traitée : Viral Pneumonia-999.png
# Image 1345/1345 traitée : Viral Pneumonia-999.png
# DataFrame shape : (1345, 16393)
# Displaying statistics for pneumonia_128x128_masked...
# DataFrame shape : (1345, 16393)
# Displaying statistics for pneumonia_128x128_masked...
#       nbr_pixels_affiches  total_pixels  ratio_pixels_affiches  \
# 0                    3959         16384               0.241638
# 1                    4427         16384               0.270203
# 2                    3897         16384               0.237854
# 3                    4163         16384               0.254089
# 4                    2541         16384               0.155090
# ...                   ...           ...                    ...
# 3611                 2227         16384               0.135925
# 3612                 7046         16384               0.430054
# 3613                 3120         16384               0.190430
# 3614                 2250         16384               0.137329
# 3615                 7026         16384               0.428833
#
#       pourcentage_pixels_affiches  luminosite_image_complete  \
# 0                       24.163818                 145.894592
# 1                       27.020264                 141.354309
# 2                       23.785400                 152.881348
# 3                       25.408936                 162.769653
# 4                       15.509033                 129.887024
# ...                           ...                        ...
# 3611                    13.592529                 146.743103
# 3612                    43.005371                 141.032715
# 3613                    19.042969                 119.463013
# 3614                    13.732910                 134.764038
# 3615                    42.883301                 160.838501
#
#       contraste_image_complete  luminosite_zone_masquee  \
# 0                    51.687549               127.638040
# 1                    40.481342               122.688502
# 2                    73.566028               122.204260
# 3                    76.053274               136.714869
# 4                    65.920745               128.184179
# ...                        ...                      ...
# 3611                 44.053278               134.506062
# 3612                 44.006632               112.197985
# 3613                 61.207762                96.792308
# 3614                 64.078460               157.874667
# 3615                 47.583432               121.133077
#
#       contraste_zone_masquee                  FileName
# 0                  28.064941  pneumonia_128x128_masked
# 1                  23.102425  pneumonia_128x128_masked
# 2                  41.904762  pneumonia_128x128_masked
# 3                  48.427833  pneumonia_128x128_masked
# 4                  30.011291  pneumonia_128x128_masked
# ...                      ...                       ...
# 3611               27.741742  pneumonia_128x128_masked
# 3612               30.996806  pneumonia_128x128_masked
# 3613               28.461002  pneumonia_128x128_masked
# 3614               30.521458  pneumonia_128x128_masked
# 3615               33.845773  pneumonia_128x128_masked
#
# [3616 rows x 9 columns]
#        nbr_pixels_affiches  total_pixels  ratio_pixels_affiches  \
# count          3616.000000        3616.0            3616.000000
# mean           4137.864768       16384.0               0.252555
# std            1221.310556           0.0               0.074543
# min             675.000000       16384.0               0.041199
# 25%            3242.000000       16384.0               0.197876
# 50%            3957.500000       16384.0               0.241547
# 75%            4846.500000       16384.0               0.295807
# max            9671.000000       16384.0               0.590271
#
#        pourcentage_pixels_affiches  luminosite_image_complete  \
# count                  3616.000000                3616.000000
# mean                     25.255522                 139.520791
# std                       7.454288                  25.029932
# min                       4.119873                  25.510559
# 25%                      19.787598                 126.884140
# 50%                      24.154663                 142.589569
# 75%                      29.580688                 155.971039
# max                      59.027100                 216.561951
#
#        contraste_image_complete  luminosite_zone_masquee  \
# count               3616.000000              3616.000000
# mean                  54.389797               114.471875
# std                   14.824722                24.382080
# min                   14.068327                22.128942
# 25%                   44.839642                98.933346
# 50%                   53.801710               116.184502
# 75%                   63.185046               131.397855
# max                  106.735764               214.155855
#
#        contraste_zone_masquee
# count             3616.000000
# mean                30.291705
# std                  9.524391
# min                  5.345058
# 25%                 22.823992
# 50%                 29.469328
# 75%                 36.381046
# max                 68.931855
#    nbr_pixels_affiches  total_pixels  ratio_pixels_affiches  \
# 0                 3959         16384               0.241638
# 1                 4427         16384               0.270203
# 2                 3897         16384               0.237854
# 3                 4163         16384               0.254089
# 4                 2541         16384               0.155090
#
#    pourcentage_pixels_affiches  luminosite_image_complete  \
# 0                    24.163818                 145.894592
# 1                    27.020264                 141.354309
# 2                    23.785400                 152.881348
# 3                    25.408936                 162.769653
# 4                    15.509033                 129.887024
#
#    contraste_image_complete  luminosite_zone_masquee  contraste_zone_masquee  \
# 0                 51.687549               127.638040               28.064941
# 1                 40.481342               122.688502               23.102425
# 2                 73.566028               122.204260               41.904762
# 3                 76.053274               136.714869               48.427833
# 4                 65.920745               128.184179               30.011291
#
#                    FileName
# 0  pneumonia_128x128_masked
# 1  pneumonia_128x128_masked
# 2  pneumonia_128x128_masked
# 3  pneumonia_128x128_masked
# 4  pneumonia_128x128_masked
# Displaying statistics for pneumonia_128x128_masked...
#        nbr_pixels_affiches  total_pixels  ratio_pixels_affiches  \
# 0                     3978         16384               0.242798
# 1                     4459         16384               0.272156
# 2                     4195         16384               0.256042
# 3                     2884         16384               0.176025
# 4                     3489         16384               0.212952
# ...                    ...           ...                    ...
# 10187                 4769         16384               0.291077
# 10188                 5636         16384               0.343994
# 10189                 4211         16384               0.257019
# 10190                 4861         16384               0.296692
# 10191                 3039         16384               0.185486
#
#        pourcentage_pixels_affiches  luminosite_image_complete  \
# 0                        24.279785                  85.188721
# 1                        27.215576                 128.522095
# 2                        25.604248                 125.681335
# 3                        17.602539                 113.723999
# 4                        21.295166                 131.352478
# ...                            ...                        ...
# 10187                    29.107666                 120.034180
# 10188                    34.399414                 134.407043
# 10189                    25.701904                 129.846985
# 10190                    29.669189                 156.804016
# 10191                    18.548584                 128.138306
#
#        contraste_image_complete  luminosite_zone_masquee  \
# 0                     70.892706               102.092257
# 1                     65.143861                74.679973
# 2                     59.393251                99.221216
# 3                     54.305213               101.614424
# 4                     65.655907                86.047005
# ...                         ...                      ...
# 10187                 71.309267                72.178025
# 10188                 59.086660               114.828602
# 10189                 72.730342                77.838993
# 10190                 62.941133               119.850031
# 10191                 72.093985                68.368871
#
#        contraste_zone_masquee                  FileName
# 0                   30.811894  pneumonia_128x128_masked
# 1                   32.044396  pneumonia_128x128_masked
# 2                   29.190961  pneumonia_128x128_masked
# 3                   24.048979  pneumonia_128x128_masked
# 4                   33.830230  pneumonia_128x128_masked
# ...                       ...                       ...
# 10187               31.710190  pneumonia_128x128_masked
# 10188               35.114399  pneumonia_128x128_masked
# 10189               40.131513  pneumonia_128x128_masked
# 10190               37.943921  pneumonia_128x128_masked
# 10191               33.076972  pneumonia_128x128_masked
#
# [10192 rows x 9 columns]
#        nbr_pixels_affiches  total_pixels  ratio_pixels_affiches  \
# count         10192.000000       10192.0           10192.000000
# mean           4257.004317       16384.0               0.259827
# std             968.980751           0.0               0.059142
# min             596.000000       16384.0               0.036377
# 25%            3605.000000       16384.0               0.220032
# 50%            4221.000000       16384.0               0.257629
# 75%            4893.000000       16384.0               0.298645
# max            7687.000000       16384.0               0.469177
#
#        pourcentage_pixels_affiches  luminosite_image_complete  \
# count                 10192.000000               10192.000000
# mean                     25.982692                 129.389647
# std                       5.914189                  22.448906
# min                       3.637695                  26.440125
# 25%                      22.003174                 113.522995
# 50%                      25.762939                 125.508545
# 75%                      29.864502                 143.643478
# max                      46.917725                 201.850891
#
#        contraste_image_complete  luminosite_zone_masquee  \
# count              10192.000000             10192.000000
# mean                  61.273567                97.884023
# std                    9.556274                24.657277
# min                   19.037936                20.176888
# 25%                   55.663048                77.764993
# 50%                   63.202873                91.474315
# 75%                   68.165908               115.944557
# max                   98.538314               181.219793
#
#        contraste_zone_masquee
# count            10192.000000
# mean                31.189724
# std                  5.516721
# min                  6.873319
# 25%                 28.351396
# 50%                 31.706606
# 75%                 34.694766
# max                 51.096419
#    nbr_pixels_affiches  total_pixels  ratio_pixels_affiches  \
# 0                 3978         16384               0.242798
# 1                 4459         16384               0.272156
# 2                 4195         16384               0.256042
# 3                 2884         16384               0.176025
# 4                 3489         16384               0.212952
#
#    pourcentage_pixels_affiches  luminosite_image_complete  \
# 0                    24.279785                  85.188721
# 1                    27.215576                 128.522095
# 2                    25.604248                 125.681335
# 3                    17.602539                 113.723999
# 4                    21.295166                 131.352478
#
#    contraste_image_complete  luminosite_zone_masquee  contraste_zone_masquee  \
# 0                 70.892706               102.092257               30.811894
# 1                 65.143861                74.679973               32.044396
# 2                 59.393251                99.221216               29.190961
# 3                 54.305213               101.614424               24.048979
# 4                 65.655907                86.047005               33.830230
#
#                    FileName
# 0  pneumonia_128x128_masked
# 1  pneumonia_128x128_masked
# 2  pneumonia_128x128_masked
# 3  pneumonia_128x128_masked
# 4  pneumonia_128x128_masked
# Displaying statistics for pneumonia_128x128_masked...
#       nbr_pixels_affiches  total_pixels  ratio_pixels_affiches  \
# 0                    4002         16384               0.244263
# 1                    3577         16384               0.218323
# 2                    3684         16384               0.224854
# 3                    4512         16384               0.275391
# 4                    4855         16384               0.296326
# ...                   ...           ...                    ...
# 6007                 4102         16384               0.250366
# 6008                 2635         16384               0.160828
# 6009                 2625         16384               0.160217
# 6010                 2432         16384               0.148438
# 6011                 2708         16384               0.165283
#
#       pourcentage_pixels_affiches  luminosite_image_complete  \
# 0                       24.426270                  94.549988
# 1                       21.832275                 162.394287
# 2                       22.485352                 119.096130
# 3                       27.539062                 150.930054
# 4                       29.632568                 110.661865
# ...                           ...                        ...
# 6007                    25.036621                 128.743591
# 6008                    16.082764                 119.843750
# 6009                    16.021729                 112.638672
# 6010                    14.843750                 123.243896
# 6011                    16.528320                  85.410522
#
#       contraste_image_complete  luminosite_zone_masquee  \
# 0                    68.214122                51.895302
# 1                    43.588283               163.469388
# 2                    62.007085                86.992400
# 3                    45.674430               154.917996
# 4                    42.871547                96.769722
# ...                        ...                      ...
# 6007                 59.739631               128.755485
# 6008                 45.995224               124.598102
# 6009                 56.718208               108.340190
# 6010                 58.318379                96.635280
# 6011                 52.414384                76.470089
#
#       contraste_zone_masquee                  FileName
# 0                  41.360107  pneumonia_128x128_masked
# 1                  14.429268  pneumonia_128x128_masked
# 2                  29.562168  pneumonia_128x128_masked
# 3                  13.201669  pneumonia_128x128_masked
# 4                  18.081692  pneumonia_128x128_masked
# ...                      ...                       ...
# 6007               21.958883  pneumonia_128x128_masked
# 6008               20.653511  pneumonia_128x128_masked
# 6009               18.970706  pneumonia_128x128_masked
# 6010               23.588923  pneumonia_128x128_masked
# 6011               17.419392  pneumonia_128x128_masked
#
# [6012 rows x 9 columns]
#        nbr_pixels_affiches  total_pixels  ratio_pixels_affiches  \
# count          6012.000000        6012.0            6012.000000
# mean           3647.330838       16384.0               0.222615
# std             921.014574           0.0               0.056214
# min             502.000000       16384.0               0.030640
# 25%            3013.000000       16384.0               0.183899
# 50%            3590.000000       16384.0               0.219116
# 75%            4213.000000       16384.0               0.257141
# max            7520.000000       16384.0               0.458984
#
#        pourcentage_pixels_affiches  luminosite_image_complete  \
# count                  6012.000000                6012.000000
# mean                     22.261541                 126.021483
# std                       5.621427                  23.570662
# min                       3.063965                  32.226562
# 25%                      18.389893                 110.576950
# 50%                      21.911621                 120.817932
# 75%                      25.714111                 142.100922
# max                      45.898438                 229.143066
#
#        contraste_image_complete  luminosite_zone_masquee  \
# count               6012.000000              6012.000000
# mean                  57.121131               114.378883
# std                    9.801557                26.664310
# min                   26.656370                25.694085
# 25%                   50.148061                94.391904
# 50%                   56.701549               111.449267
# 75%                   63.927696               133.115198
# max                   93.101226               208.486667
#
#        contraste_zone_masquee
# count             6012.000000
# mean                27.190672
# std                  8.323597
# min                  5.143849
# 25%                 21.167183
# 50%                 26.661710
# 75%                 32.281310
# max                 74.727968
#    nbr_pixels_affiches  total_pixels  ratio_pixels_affiches  \
# 0                 4002         16384               0.244263
# 1                 3577         16384               0.218323
# 2                 3684         16384               0.224854
# 3                 4512         16384               0.275391
# 4                 4855         16384               0.296326
#
#    pourcentage_pixels_affiches  luminosite_image_complete  \
# 0                    24.426270                  94.549988
# 1                    21.832275                 162.394287
# 2                    22.485352                 119.096130
# 3                    27.539062                 150.930054
# 4                    29.632568                 110.661865
#
#    contraste_image_complete  luminosite_zone_masquee  contraste_zone_masquee  \
# 0                 68.214122                51.895302               41.360107
# 1                 43.588283               163.469388               14.429268
# 2                 62.007085                86.992400               29.562168
# 3                 45.674430               154.917996               13.201669
# 4                 42.871547                96.769722               18.081692
#
#                    FileName
# 0  pneumonia_128x128_masked
# 1  pneumonia_128x128_masked
# 2  pneumonia_128x128_masked
# 3  pneumonia_128x128_masked
# 4  pneumonia_128x128_masked
# Displaying statistics for pneumonia_128x128_masked...
#       nbr_pixels_affiches  total_pixels  ratio_pixels_affiches  \
# 0                    3734         16384               0.227905
# 1                    5014         16384               0.306030
# 2                    4060         16384               0.247803
# 3                    3436         16384               0.209717
# 4                    5442         16384               0.332153
# ...                   ...           ...                    ...
# 1340                 4924         16384               0.300537
# 1341                 4389         16384               0.267883
# 1342                 5729         16384               0.349670
# 1343                 3659         16384               0.223328
# 1344                 2864         16384               0.174805
#
#       pourcentage_pixels_affiches  luminosite_image_complete  \
# 0                       22.790527                 121.498657
# 1                       30.603027                 132.667175
# 2                       24.780273                 121.967468
# 3                       20.971680                 122.931946
# 4                       33.215332                 166.230530
# ...                           ...                        ...
# 1340                    30.053711                 120.339539
# 1341                    26.788330                 120.856323
# 1342                    34.967041                 118.228577
# 1343                    22.332764                 143.849854
# 1344                    17.480469                 126.111938
#
#       contraste_image_complete  luminosite_zone_masquee  \
# 0                    59.412996               116.634440
# 1                    48.890553               134.108097
# 2                    66.469504               117.215764
# 3                    63.819746               116.580326
# 4                    46.192766               156.271040
# ...                        ...                      ...
# 1340                 51.363525                89.715881
# 1341                 58.547216                95.807473
# 1342                 54.768207                87.268284
# 1343                 42.117558               121.603170
# 1344                 47.041945               124.309707
#
#       contraste_zone_masquee                  FileName
# 0                  24.667440  pneumonia_128x128_masked
# 1                  28.389076  pneumonia_128x128_masked
# 2                  27.123350  pneumonia_128x128_masked
# 3                  28.218231  pneumonia_128x128_masked
# 4                  27.532952  pneumonia_128x128_masked
# ...                      ...                       ...
# 1340               27.965518  pneumonia_128x128_masked
# 1341               31.804764  pneumonia_128x128_masked
# 1342               33.562349  pneumonia_128x128_masked
# 1343               26.185652  pneumonia_128x128_masked
# 1344               16.236299  pneumonia_128x128_masked
#
# [1345 rows x 9 columns]
#        nbr_pixels_affiches  total_pixels  ratio_pixels_affiches  \
# count          1345.000000        1345.0            1345.000000
# mean           3957.876580       16384.0               0.241570
# std             846.866094           0.0               0.051689
# min            1775.000000       16384.0               0.108337
# 25%            3369.000000       16384.0               0.205627
# 50%            3921.000000       16384.0               0.239319
# 75%            4464.000000       16384.0               0.272461
# max            7776.000000       16384.0               0.474609
#
#        pourcentage_pixels_affiches  luminosite_image_complete  \
# count                  1345.000000                1345.000000
# mean                     24.156962                 125.369125
# std                       5.168860                  18.981007
# min                      10.833740                  64.774902
# 25%                      20.562744                 113.499023
# 50%                      23.931885                 126.857178
# 75%                      27.246094                 137.784790
# max                      47.460938                 193.695129
#
#        contraste_image_complete  luminosite_zone_masquee  \
# count               1345.000000              1345.000000
# mean                  58.485935               117.462289
# std                   10.757478                22.238624
# min                   24.089776                47.496263
# 25%                   51.036924               102.960599
# 50%                   59.402248               118.482222
# 75%                   66.652289               131.618634
# max                   87.163242               193.329230
#
#        contraste_zone_masquee
# count             1345.000000
# mean                26.507619
# std                  5.640598
# min                  9.937772
# 25%                 22.997320
# 50%                 27.123350
# 75%                 30.186514
# max                 49.545438
#    nbr_pixels_affiches  total_pixels  ratio_pixels_affiches  \
# 0                 3734         16384               0.227905
# 1                 5014         16384               0.306030
# 2                 4060         16384               0.247803
# 3                 3436         16384               0.209717
# 4                 5442         16384               0.332153
#
#    pourcentage_pixels_affiches  luminosite_image_complete  \
# 0                    22.790527                 121.498657
# 1                    30.603027                 132.667175
# 2                    24.780273                 121.967468
# 3                    20.971680                 122.931946
# 4                    33.215332                 166.230530
#
#    contraste_image_complete  luminosite_zone_masquee  contraste_zone_masquee  \
# 0                 59.412996               116.634440               24.667440
# 1                 48.890553               134.108097               28.389076
# 2                 66.469504               117.215764               27.123350
# 3                 63.819746               116.580326               28.218231
# 4                 46.192766               156.271040               27.532952
#
#                    FileName
# 0  pneumonia_128x128_masked
# 1  pneumonia_128x128_masked
# 2  pneumonia_128x128_masked
# 3  pneumonia_128x128_masked
# 4  pneumonia_128x128_masked

# %%
# Comparaison des valeurs de chaque catégorie par métrique avec un diagramme chart (boxplot)
import matplotlib.pyplot as plt
import seaborn as sns

# Reconstituer les DataFrames de stats pour chaque catégorie à partir de Stats
all_stats = []
for key, stats_list in Stats.items():
    df_stats = pd.DataFrame(stats_list)
    df_stats['Categorie'] = key
    all_stats.append(df_stats)

# Concaténer tous les DataFrames
df_all = pd.concat(all_stats, ignore_index=True)

# Sélectionner les colonnes numériques à comparer (hors FileName/Categorie)
metrics = [col for col in df_all.columns if col not in ['FileName', 'Categorie']]

# Afficher un diagramme en boîte (boxplot) pour chaque métrique par catégorie
plt.figure(figsize=(16,10))
for i, metric in enumerate(metrics):
    plt.subplot(1, len(metrics), i+1)
    sns.boxplot(x='Categorie', y=metric, data=df_all)
    plt.title(metric)
    plt.xlabel('Categorie')
    plt.ylabel(metric)
plt.tight_layout()
plt.suptitle('Comparaison des métriques par catégorie', y=1.05)
plt.show()

# %%
# Affichage fusionné : histogramme + barplot comparatif des moyennes pour chaque métrique
import matplotlib.pyplot as plt
import seaborn as sns

# Calcul des moyennes par catégorie pour chaque métrique
df_means = df_all.groupby('Categorie')[metrics].mean().reset_index()

for metric in metrics:
    fig, axes = plt.subplots(1, 2, figsize=(16, 4))

    # Histogramme pour toutes les catégories
    sns.histplot(data=df_all, x=metric, hue='Categorie', element='step', stat='density', common_norm=False, bins=30, palette='tab10', alpha=0.6, ax=axes[0])
    axes[0].set_title(f"Distribution de {metric} par catégorie")
    axes[0].set_xlabel(metric)
    axes[0].set_ylabel('Densité')
    axes[0].legend(title='Categorie')

    # Barplot comparatif des moyennes pour toutes les catégories
    sns.barplot(data=df_means, x='Categorie', y=metric, palette='tab10', ax=axes[1])
    axes[1].set_title(f"Moyenne de {metric} par catégorie")
    axes[1].set_xlabel('Categorie')
    axes[1].set_ylabel(f"Moyenne de {metric}")

    #rajouter les valeurs numériques au-dessus des barres
    for p in axes[1].patches:
        axes[1].annotate(f'{p.get_height():.2f}', 
                         (p.get_x() + p.get_width() / 2., p.get_height()), 
                         ha='center', va='bottom', fontsize=10, color='black')

    # Ajustement de la mise en page
    plt.suptitle(f"Analyse de {metric} par catégorie", y=1.05)
    plt.tight_layout()
    plt.show()
# Out:
# C:\Utilisateurs\Léna\AppData\Local\Temp\ipykernel_20516\2581736398.py:16: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[0].legend(title='Categorie')
# C:\Utilisateurs\Léna\AppData\Local\Temp\ipykernel_20516\2581736398.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_means, x='Categorie', y=metric, palette='tab10', ax=axes[1])
# C:\Utilisateurs\Léna\AppData\Local\Temp\ipykernel_20516\2581736398.py:16: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[0].legend(title='Categorie')
# C:\Utilisateurs\Léna\AppData\Local\Temp\ipykernel_20516\2581736398.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_means, x='Categorie', y=metric, palette='tab10', ax=axes[1])
# C:\Utilisateurs\Léna\AppData\Local\Temp\ipykernel_20516\2581736398.py:16: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[0].legend(title='Categorie')
# C:\Utilisateurs\Léna\AppData\Local\Temp\ipykernel_20516\2581736398.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_means, x='Categorie', y=metric, palette='tab10', ax=axes[1])
# C:\Utilisateurs\Léna\AppData\Local\Temp\ipykernel_20516\2581736398.py:16: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[0].legend(title='Categorie')
# C:\Utilisateurs\Léna\AppData\Local\Temp\ipykernel_20516\2581736398.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_means, x='Categorie', y=metric, palette='tab10', ax=axes[1])
# C:\Utilisateurs\Léna\AppData\Local\Temp\ipykernel_20516\2581736398.py:16: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[0].legend(title='Categorie')
# C:\Utilisateurs\Léna\AppData\Local\Temp\ipykernel_20516\2581736398.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_means, x='Categorie', y=metric, palette='tab10', ax=axes[1])
# C:\Utilisateurs\Léna\AppData\Local\Temp\ipykernel_20516\2581736398.py:16: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[0].legend(title='Categorie')
# C:\Utilisateurs\Léna\AppData\Local\Temp\ipykernel_20516\2581736398.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_means, x='Categorie', y=metric, palette='tab10', ax=axes[1])
# C:\Utilisateurs\Léna\AppData\Local\Temp\ipykernel_20516\2581736398.py:16: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[0].legend(title='Categorie')
# C:\Utilisateurs\Léna\AppData\Local\Temp\ipykernel_20516\2581736398.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_means, x='Categorie', y=metric, palette='tab10', ax=axes[1])
# C:\Utilisateurs\Léna\AppData\Local\Temp\ipykernel_20516\2581736398.py:16: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[0].legend(title='Categorie')
# C:\Utilisateurs\Léna\AppData\Local\Temp\ipykernel_20516\2581736398.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_means, x='Categorie', y=metric, palette='tab10', ax=axes[1])
